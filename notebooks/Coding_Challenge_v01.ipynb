# %% [markdown]
# # HUK Coburg Coding Challenge
#
# ## 01 | Setting up the environment

# %%
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_curve, recall_score
from sklearn.model_selection import train_test_split

import xgboost as xgb


sns.set_palette(sns.color_palette("Dark2"))
RANDOM_STATE = 43

DATA_D01_FOLDER_PATH = "data/d01/"
DATA_D02_FOLDER_PATH = "data/d02/"
DATA_D03_FOLDER_PATH = "data/d03_submission/"

df_per = pd.read_csv(os.path.join(DATA_D01_FOLDER_PATH, "alter_geschlecht.csv"))
df_int = pd.read_csv(os.path.join(DATA_D01_FOLDER_PATH, "interesse.csv"))
df_res = pd.read_csv(os.path.join(DATA_D01_FOLDER_PATH, "rest.csv"), sep=";")

print("Personal data shape: ", df_per.shape)
print("Interest data shape: ", df_int.shape)  # -> less observations
print("Rest data shape: ", df_res.shape)
# Out:
# Personal data shape:  (508146, 3)
# Interest data shape:  (381109, 2)
# Rest data shape:  (508146, 9)

# %% [markdown]
# | Variable Name   | Type       | Description                                                                 | Prior Assumption                                                                                   |
# |-----------------|------------|-----------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------|
# | ID              | Integer    | Eindeutige ID des Kunden                                                    | Keine direkte Auswirkung auf Interesse                                                             |
# | Geschlecht      | Categorical| Geschlecht des Kunden (z.B. männlich/weiblich)                              | Mögliche Unterschiede in der Affinität je nach Geschlecht                                           |
# | Alter           | Integer    | Alter des Kunden in Jahren                                                  | Jüngere oder ältere Altersgruppen könnten unterschiedlich interessiert sein                        |
# | Fahrerlaubnis   | Binary     | Ob der Kunde eine Fahrerlaubnis besitzt (Ja=1, Nein=0)                      | Kunden ohne Fahrerlaubnis zeigen vermutlich kein Interesse                                         |
# | Regional_Code   | Float      | Eindeutiger Code der Wohnregion des Kunden                                  | Regionale Unterschiede könnten das Interesse beeinflussen                                          |
# | Vorversicherung | Binary     | Ob der Kunde bereits eine Kfz-Versicherung hat (Ja=1, Nein=0)               | Kunden ohne Vorversicherung könnten eher interessiert sein                                         |
# | Alter_Fzg       | String     | Alter des Fahrzeugs des Kunden ("1-2 Year" etc.)                            | Besitzer neuerer Fahrzeuge könnten eher Interesse zeigen                                           |
# | Vorschaden      | Binary     | Ob der Kunde bereits einen Schaden am Fahrzeug hatte (Yes, No)              | Kunden mit Vorschäden könnten verstärktes Interesse an einem besseren Angebot haben                |
# | Jahresbeitrag   | Float      | Erwarteter Jahresbeitrag in Euro bei Abschluss der Versicherung             | Höhere Beiträge könnten das Interesse negativ beeinflussen                                         |
# | Vertriebskanal  | Float      | Code für den genutzten Vertriebskanal                                       | Bestimmte Vertriebskanäle könnten erfolgreicher im Wecken des Interesses sein                      |
# | Kundentreue     | Integer    | Anzahl der Tage, seit denen eine Kundenbeziehung besteht                    | Längere Kundentreue könnte mit höherem Interesse korrelieren                                       |
# | Interesse       | Binary     | Zielvariable: Ob der Kunde an einem Versicherungsangebot interessiert ist (Ja=1, Nein=0) | -                                                                                     |
#
# **Checks:**
# - ✅ All data sets only contain unique IDs
# - ❓ Interest dataframe has less rows than the other dataframes --> assumption: missing values are test data since max interest id is 381109 (= length of interest dataframe)
# - ✅ Otherwise no missing values in any dataframe
# - ❌ How is this sample generated and who is the target group?
# - ❓ `Jahresbeitrag` might be endogenous since it could had been calculated from the other variables

# %% [markdown]
# ## 02 | Prepare the Data

# %%
LABEL = "Interesse"
CAT_FEATS = ["Geschlecht", "Fahrerlaubnis", "Regional_Code", "Vorversicherung", "Alter_Fzg", "Vorschaden", "Vertriebskanal"]
NUM_FEATS = ["Alter", "Jahresbeitrag", "Kundentreue"]

# Create dataframe that contains all entries with a label value
df_raw = pd.merge(pd.merge(df_int, df_per, on="id"), df_res, on="id")

# Create another dataframe that contains all entries with no label value
df_raw_no_label = pd.merge(df_per, df_res, on="id")
df_raw_no_label = df_raw_no_label[~df_raw_no_label["id"].isin(df_raw["id"])]

# %%
def preprocess_data(df: pd.DataFrame, test_df = False) -> pd.DataFrame:
    mapping_dict = {
        "Geschlecht": {"Male": 0, "Female": 1},
        "Vorschaden": {"No": 0, "Yes": 1},
        "Alter_Fzg": {"< 1 Year": 0, "1-2 Year": 1, "> 2 Years": 2}
    }
    for col, mapping in mapping_dict.items():
        df[col] = df[col].map(mapping).astype("int8")
    int8_columns = ["Vorversicherung", "Alter", "Fahrerlaubnis", "Regional_Code"]
    df[int8_columns] = df[int8_columns].astype("int8")
    int16_columns = ["Vertriebskanal", "Kundentreue"]
    df[int16_columns] = df[int16_columns].astype("int16")
    if not test_df:
        df["Interesse"] = df["Interesse"].astype("int8")
    return df["id"], df.drop(columns="id")

df_ids, df = preprocess_data(df_raw.copy())
df_no_label_ids, df_no_label = preprocess_data(df_raw_no_label.copy(), test_df=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Interesse        381109 non-null  int8
#  1   Geschlecht       381109 non-null  int8
#  2   Alter            381109 non-null  int8
#  3   Fahrerlaubnis    381109 non-null  int8
#  4   Regional_Code    381109 non-null  int8
#  5   Vorversicherung  381109 non-null  int8
#  6   Alter_Fzg        381109 non-null  int8
#  7   Vorschaden       381109 non-null  int8
#  8   Jahresbeitrag    381109 non-null  float64
#  9   Vertriebskanal   381109 non-null  int16
#  10  Kundentreue      381109 non-null  int16
# dtypes: float64(1), int16(2), int8(8)
# memory usage: 7.3 MB

# %% [markdown]
# ## 03 | Descriptive Statistics (=Explorative Datenanalyse)

# %%
df
# Out:
#         Interesse  Geschlecht  Alter  Fahrerlaubnis  Regional_Code  \
# 0               1           0     44              1             28
# 1               0           0     76              1              3
# 2               1           0     47              1             28
# 3               0           0     21              1             11
# 4               0           1     29              1             41
# ...           ...         ...    ...            ...            ...
# 381104          0           0     74              1             26
# 381105          0           0     30              1             37
# 381106          0           0     21              1             30
# 381107          0           1     68              1             14
# 381108          0           0     46              1             29
#
#         Vorversicherung  Alter_Fzg  Vorschaden  Jahresbeitrag  Vertriebskanal  \
# 0                     0          2           1        40454.0              26
# 1                     0          1           0        33536.0              26
# 2                     0          2           1        38294.0              26
# 3                     1          0           0        28619.0             152
# 4                     1          0           0        27496.0             152
# ...                 ...        ...         ...            ...             ...
# 381104                1          1           0        30170.0              26
# 381105                1          0           0        40016.0             152
# 381106                1          0           0        35118.0             160
# 381107                0          2           1        44617.0             124
# 381108                0          1           0        41777.0              26
#
#         Kundentreue
# 0               217
# 1               183
# 2                27
# 3               203
# 4                39
# ...             ...
# 381104           88
# 381105          131
# 381106          161
# 381107           74
# 381108          237
#
# [381109 rows x 11 columns]

# %%
df_descr = df.describe(include="all")
df_descr.loc["mode"] = df.mode().iloc[0]
df_descr.loc["nunique"] = df.nunique()
df_descr
# Out:
#              Interesse     Geschlecht          Alter  Fahrerlaubnis  \
# count    381109.000000  381109.000000  381109.000000  381109.000000
# mean          0.122563       0.459239      38.822584       0.997869
# std           0.327936       0.498336      15.511611       0.046110
# min           0.000000       0.000000      20.000000       0.000000
# 25%           0.000000       0.000000      25.000000       1.000000
# 50%           0.000000       0.000000      36.000000       1.000000
# 75%           0.000000       1.000000      49.000000       1.000000
# max           1.000000       1.000000      85.000000       1.000000
# mode          0.000000       0.000000      24.000000       1.000000
# nunique       2.000000       2.000000      66.000000       2.000000
#
#          Regional_Code  Vorversicherung      Alter_Fzg     Vorschaden  \
# count    381109.000000    381109.000000  381109.000000  381109.000000
# mean         26.388807         0.458210       0.609616       0.504877
# std          13.229888         0.498251       0.567439       0.499977
# min           0.000000         0.000000       0.000000       0.000000
# 25%          15.000000         0.000000       0.000000       0.000000
# 50%          28.000000         0.000000       1.000000       1.000000
# 75%          35.000000         1.000000       1.000000       1.000000
# max          52.000000         1.000000       2.000000       1.000000
# mode         28.000000         0.000000       1.000000       1.000000
# nunique      53.000000         2.000000       3.000000       2.000000
#
#          Jahresbeitrag  Vertriebskanal    Kundentreue
# count    381109.000000   381109.000000  381109.000000
# mean      30564.389581      112.034295     154.347397
# std       17213.155057       54.203995      83.671304
# min        2630.000000        1.000000      10.000000
# 25%       24405.000000       29.000000      82.000000
# 50%       31669.000000      133.000000     154.000000
# 75%       39400.000000      152.000000     227.000000
# max      540165.000000      163.000000     299.000000
# mode       2630.000000      152.000000     256.000000
# nunique   48838.000000      155.000000     290.000000

# %% [markdown]
# **Key overall insights**
# - The dataset contains 381,109 unique customers
# - ~12.2% of customers are interested in an insurance offer (baseline)
# - Minimum `Alter` is 20, interesting since German driving license can be obtained at 18
# - 99.8% of customers have a driving license `Fahrerlaubnis` (--> question: is the customer always the driver?)
# - `Jahresbeitrag` looks strange:
#   - Maximum value is ~0.5 million EUR (outlier)
#   - Generally, for a yearly insurance fee the values are very high. Double checked with https://www.huk.de/tarifrechner/pkw/angebot (Lambo, high risk profile: max. ~40k EUR)
# - Max `Kundentreue` is 299 which is only ~10 months.
#
# **Assumptions and Questions**
# - `Jahresbeitrag` is either
#   - Wrongly scaled (e.g. expected lifetime fee instead of yearly fee) --> *GOTO OPTION.* variable description explains "Erwarteter Versicherungsbeitrag bei Abschluss in €", i.e. not mentioning "yearly"
#   - Wrongly recorded (e.g. in a different currency)
#   - Wrong units (e.g. cents instead of full EUR)

# %% [markdown]
# ### 03.1 | Categorical Variables

# %%
# Code copied from https://www.kaggle.com/code/markuslill/s3e26-xgbclassifer
plt.figure(figsize=(14, len(CAT_FEATS) * 2))
for i, col in enumerate(CAT_FEATS):
    plt.subplot(len(CAT_FEATS) // 2 + 1, 3, i + 1)
    sns.countplot(x=col, hue=LABEL, data=df)
    plt.title(f"{col} vs {LABEL}")
    plt.tight_layout()

# %% [markdown]
# **Key overall insights**
# - People with no `Vorschaden` are less likely to be interested in an insurance offer ("not faced with the need/benefits"). These might be new (young) drivers or people with a good driving record.
# - Only little data availbe for cars with `Age_Fzg` "> 2 Years", seems like only new cars are insured (why?). Might be due to the fact that new cars are more expensive and therefore more likely to be insured.
# - There seem to be few `Vertriebskanal`s that are very successful in reaching out to customers (yet not successful in converting them to customers).
# - Same for `Regional_Code`s, some regions are more likely to have interested customers.
#   - There seems to be one region with a very high interest rate (Region 28), could be because of certain demographics or other factors.
#
# **Assumptions and Questions**
# - This might be a "(Voll-)Kasko" insurance data set (since only new cars are insured). This could explain why everyone is already "Kfz-Versicherungskunden" (car insurance customers) since car owner need a minimum insurance ("Kfz-Haftpflich"). HUK wants to offer a new (ontop) insurance service.
# - Unclear how the data is sampled. Data description mentions that the people are already "Kfz-Versicherungskunden" (car insurance customers). Does this mean that the data is biased towards people who are already insured? If so, how does this affect the model?
# - High active `Vertriebskanal`s might be digital channels (e.g. online ads, social media, etc.). Maybe younger people are more likely to be reached by these channels?

# %% [markdown]
# ### 03.2 | Numerical Variables

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 5))
for i, ax in enumerate(axes.flatten()):
    sns.violinplot(x=LABEL, y=NUM_FEATS[i], data=df, ax=ax, hue=LABEL)
    ax.set_title(f"{NUM_FEATS[i]} vs {LABEL}")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Assumptions and Questions**
# - High premiums could be explained by very expensive cars (e.g. sports cars, luxury cars, etc.), but still the values seem very high.
# - `Alter` shows that there is a bulk of non interested customers in the age group 20-27. This could be due to the fact that younger people are less likely to be interested in insurance offers (e.g. because they are less likely to own a car).
# - `Kundentreue` seems to be uniformly distributed. However, values might be truncated at 300 days.
#
# Let's analyze the multi-collinearity of the numerical variables.

# %%
plt.figure(figsize=(6, 4))
mask = np.triu(np.ones_like(df[NUM_FEATS].corr(), dtype=bool))
sns.heatmap(df[NUM_FEATS].corr(), annot=True, mask=mask)
plt.show()

# %% [markdown]
# No strong correlation between the numerical variables.
# Let's also check the distribution of the numerical variables.

# %%
pairplot = sns.pairplot(df[NUM_FEATS + [LABEL]].sample(frac=.01), 
                 hue=LABEL, 
                 corner=True)

# %% [markdown]
# We can see that the distribution of `Jahresbeitrag` has two peaks. This might be due to the fact that there are two different types of insurances offered (e.g. basic and premium). The basic insurance (lower peak) might be represented by a fixed premium of 2,630 EUR (mode and minimum of the distribution). The premium insurance (higher peak) might be more expensive and therefore have a higher premium.

# %% [markdown]
# ## 04 | Feature Engineering

# %%
def generate_features(df: pd.DataFrame) -> pd.DataFrame:
    # Hypothesis: Customers with no prior insurance but with past damages might have higher interest
    df["Ungedeckter_Vorschaden"] = (df["Vorversicherung"]==0)*(df["Vorschaden"]==1)*1
    # Hypothesis: Older cars might be cheaper to insure, howevere this might interact differently with the premium
    df["Oldtimer_Premium"] = df["Alter_Fzg"] * df["Jahresbeitrag"]
    # Hypothesis: Experienced drivers with a clean record might be less interested in the product
    df["Erfahrene_Fahrer"] = (df["Alter"] > 30) * (df["Fahrerlaubnis"] == 1) * 1
    # Hypothesis: New customers might be more interested in the product
    df["Neukunde"] = (df["Kundentreue"] < 30) * 1
    # Hypothesis: Young customers with a new car might be more interested in the product
    df["Junges_Fahrzeug"] = (df["Alter"] <= 22) * (df["Alter_Fzg"] == 0) * 1
    # Log transform Jahresbeitrag because it is right skewed (no impact on tree based models)
    df["Log_Jahresbeitrag"] = np.log1p(df["Jahresbeitrag"])
    # Create age bins since year of birth is not very informative
    df["Age_Bins"] = pd.qcut(df["Alter"], q=5, labels=False)
    return df

df = generate_features(df)
df_no_label = generate_features(df_no_label)

DROP_FEATS = ["Log_Jahresbeitrag", "Jahresbeitrag"]

df.to_csv(os.path.join(DATA_D02_FOLDER_PATH, "train.csv"), index=False)
df_no_label.to_csv(os.path.join(DATA_D02_FOLDER_PATH, "test.csv"), index=False)

# %% [markdown]
# ## 05 | Model Selection (=Modelvergleich)
#
# **What is the task?**
#
# The task description "Modellierung der Kundenaffinität zum Abschluss einer Kfz-Versicherung" is vague. There are two ways to interpret this:
# - [Analytical Task] Analyze the factors that influence a customer's interest in an insurance offer.
# - [Predictive Task] Predict whether a customer is interested in an insurance offer.
#
# > We assume that the task is the predictive task.
#
# **A priori which models could be used?**
#
# Analytical Task:
# - ✅ Logistic Regression, low complexity, interpretable
#
# Predictive Task:
# - ✅ XGBoost, good overall performance, good for non-linear relationships
# - ❌ Neural Network, probably too complex for the task, datset is too small
#
# **What is important, i.e. what should the model optimize?**
#
# I guess it is **less a problem** when we wrongly predict that a customer is interested in an insurance offer. However, it is a **big problem** when we wrongly predict that a customer is not interested in an insurance offer. This is because we might want to reach out to as many interested customers as possible (e.g. through marketing like mail campaigns etc.).
#
# Hence we should optimize for recall (=true positive rate). That means given an interested person we want to have a high probability in identifying her. However, as seen in the EDA the dataset is imbalanced towards the non-interested customers.
#
# **Notes**
# - Optimize for recall, while retaining a high/reasonable precision (i.e. not predicting too many false positives)
# - Imbalanced dataset (only 12.2% interested customers)
#
# **Insights**
# - ✅ `Jahresbeitrag` is an important feature however removing it improves the model performance little bit (reminder: `Jahresbeitrag` might be endogenous)

# %% [markdown]
# ## 06 Model Training and Evaluation (=Modellbuilding)

# %%
P_THRESHOLD = 0.001 # corresponds to the share of missclassified positive samples

def recall_eval(y_pred, dtrain):
    """Custom recall evaluation metric for XGBoost"""
    y_true = dtrain.get_label()
    y_pred_label = (y_pred > P_THRESHOLD).astype(int)
    recall = recall_score(y_true, y_pred_label)
    return 'recall', recall

X_train, X_valid, y_train, y_valid = train_test_split(df.drop(columns=[*DROP_FEATS, LABEL]), df[LABEL], test_size=0.2, random_state=RANDOM_STATE)

dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)

xgb_params = {
    'objective': 'binary:logistic',
    'eta': 0.1,
    'max_depth': 5,
    'seed': RANDOM_STATE
}

xgb_cl = xgb.train(
    xgb_params,
    dtrain,
    num_boost_round=200,
    evals=[(dvalid, 'test')],
    custom_metric=recall_eval,
    maximize=True,
)
# Out:
# [0]	test-logloss:0.36978	test-recall:1.00000
# [1]	test-logloss:0.35746	test-recall:1.00000
# [2]	test-logloss:0.34690	test-recall:1.00000
# [3]	test-logloss:0.33770	test-recall:1.00000
# [4]	test-logloss:0.32965	test-recall:1.00000
# [5]	test-logloss:0.32263	test-recall:1.00000
# [6]	test-logloss:0.31650	test-recall:1.00000
# [7]	test-logloss:0.31105	test-recall:1.00000
# [8]	test-logloss:0.30629	test-recall:1.00000
# [9]	test-logloss:0.30206	test-recall:1.00000
# [10]	test-logloss:0.29823	test-recall:1.00000
# [11]	test-logloss:0.29489	test-recall:1.00000
# [12]	test-logloss:0.29179	test-recall:1.00000
# [13]	test-logloss:0.28913	test-recall:1.00000
# [14]	test-logloss:0.28678	test-recall:1.00000
# [15]	test-logloss:0.28457	test-recall:1.00000
# [16]	test-logloss:0.28265	test-recall:1.00000
# [17]	test-logloss:0.28100	test-recall:1.00000
# [18]	test-logloss:0.27940	test-recall:1.00000
# [19]	test-logloss:0.27807	test-recall:1.00000
# [20]	test-logloss:0.27686	test-recall:1.00000
# [21]	test-logloss:0.27580	test-recall:1.00000
# [22]	test-logloss:0.27481	test-recall:1.00000
# [23]	test-logloss:0.27395	test-recall:1.00000
# [24]	test-logloss:0.27315	test-recall:1.00000
# [25]	test-logloss:0.27239	test-recall:1.00000
# [26]	test-logloss:0.27160	test-recall:1.00000
# [27]	test-logloss:0.27101	test-recall:1.00000
# [28]	test-logloss:0.27041	test-recall:1.00000
# [29]	test-logloss:0.26991	test-recall:1.00000
# [30]	test-logloss:0.26947	test-recall:1.00000
# [31]	test-logloss:0.26902	test-recall:1.00000
# [32]	test-logloss:0.26866	test-recall:1.00000
# [33]	test-logloss:0.26833	test-recall:1.00000
# [34]	test-logloss:0.26803	test-recall:1.00000
# [35]	test-logloss:0.26768	test-recall:1.00000
# [36]	test-logloss:0.26739	test-recall:1.00000
# [37]	test-logloss:0.26713	test-recall:1.00000
# [38]	test-logloss:0.26693	test-recall:1.00000
# [39]	test-logloss:0.26674	test-recall:1.00000
# [40]	test-logloss:0.26655	test-recall:1.00000
# [41]	test-logloss:0.26640	test-recall:1.00000
# [42]	test-logloss:0.26620	test-recall:1.00000
# [43]	test-logloss:0.26605	test-recall:1.00000
# [44]	test-logloss:0.26595	test-recall:1.00000
# [45]	test-logloss:0.26585	test-recall:1.00000
# [46]	test-logloss:0.26575	test-recall:1.00000
# [47]	test-logloss:0.26566	test-recall:1.00000
# [48]	test-logloss:0.26553	test-recall:1.00000
# [49]	test-logloss:0.26545	test-recall:1.00000
# [50]	test-logloss:0.26535	test-recall:1.00000
# [51]	test-logloss:0.26530	test-recall:1.00000
# [52]	test-logloss:0.26523	test-recall:1.00000
# [53]	test-logloss:0.26518	test-recall:1.00000
# [54]	test-logloss:0.26512	test-recall:0.99989
# [55]	test-logloss:0.26509	test-recall:0.99968
# [56]	test-logloss:0.26499	test-recall:0.99957
# [57]	test-logloss:0.26496	test-recall:0.99957
# [58]	test-logloss:0.26490	test-recall:0.99925
# [59]	test-logloss:0.26487	test-recall:0.99925
# [60]	test-logloss:0.26481	test-recall:0.99914
# [61]	test-logloss:0.26479	test-recall:0.99893
# [62]	test-logloss:0.26475	test-recall:0.99893
# [63]	test-logloss:0.26468	test-recall:0.99893
# [64]	test-logloss:0.26465	test-recall:0.99893
# [65]	test-logloss:0.26462	test-recall:0.99893
# [66]	test-logloss:0.26460	test-recall:0.99893
# [67]	test-logloss:0.26457	test-recall:0.99893
# [68]	test-logloss:0.26456	test-recall:0.99893
# [69]	test-logloss:0.26449	test-recall:0.99893
# [70]	test-logloss:0.26445	test-recall:0.99893
# [71]	test-logloss:0.26441	test-recall:0.99893
# [72]	test-logloss:0.26439	test-recall:0.99893
# [73]	test-logloss:0.26435	test-recall:0.99893
# [74]	test-logloss:0.26431	test-recall:0.99893
# [75]	test-logloss:0.26430	test-recall:0.99893
# [76]	test-logloss:0.26428	test-recall:0.99893
# [77]	test-logloss:0.26426	test-recall:0.99893
# [78]	test-logloss:0.26424	test-recall:0.99893
# [79]	test-logloss:0.26424	test-recall:0.99893
# [80]	test-logloss:0.26421	test-recall:0.99893
# [81]	test-logloss:0.26421	test-recall:0.99893
# [82]	test-logloss:0.26414	test-recall:0.99893
# [83]	test-logloss:0.26410	test-recall:0.99893
# [84]	test-logloss:0.26409	test-recall:0.99893
# [85]	test-logloss:0.26408	test-recall:0.99893
# [86]	test-logloss:0.26407	test-recall:0.99893
# [87]	test-logloss:0.26398	test-recall:0.99893
# [88]	test-logloss:0.26397	test-recall:0.99893
# [89]	test-logloss:0.26396	test-recall:0.99893
# [90]	test-logloss:0.26392	test-recall:0.99893
# [91]	test-logloss:0.26391	test-recall:0.99893
# [92]	test-logloss:0.26390	test-recall:0.99893
# [93]	test-logloss:0.26389	test-recall:0.99893
# [94]	test-logloss:0.26388	test-recall:0.99893
# [95]	test-logloss:0.26383	test-recall:0.99893
# [96]	test-logloss:0.26382	test-recall:0.99893
# [97]	test-logloss:0.26381	test-recall:0.99893
# [98]	test-logloss:0.26380	test-recall:0.99893
# [99]	test-logloss:0.26379	test-recall:0.99893
# [100]	test-logloss:0.26378	test-recall:0.99893
# [101]	test-logloss:0.26375	test-recall:0.99893
# [102]	test-logloss:0.26375	test-recall:0.99893
# [103]	test-logloss:0.26373	test-recall:0.99893
# [104]	test-logloss:0.26372	test-recall:0.99893
# [105]	test-logloss:0.26372	test-recall:0.99893
# [106]	test-logloss:0.26368	test-recall:0.99893
# [107]	test-logloss:0.26365	test-recall:0.99893
# [108]	test-logloss:0.26365	test-recall:0.99893
# [109]	test-logloss:0.26365	test-recall:0.99893
# [110]	test-logloss:0.26364	test-recall:0.99893
# [111]	test-logloss:0.26364	test-recall:0.99893
# [112]	test-logloss:0.26362	test-recall:0.99893
# [113]	test-logloss:0.26361	test-recall:0.99893
# [114]	test-logloss:0.26360	test-recall:0.99893
# [115]	test-logloss:0.26360	test-recall:0.99893
# [116]	test-logloss:0.26360	test-recall:0.99893
# [117]	test-logloss:0.26359	test-recall:0.99893
# [118]	test-logloss:0.26360	test-recall:0.99893
# [119]	test-logloss:0.26358	test-recall:0.99893
# [120]	test-logloss:0.26355	test-recall:0.99893
# [121]	test-logloss:0.26354	test-recall:0.99893
# [122]	test-logloss:0.26354	test-recall:0.99893
# [123]	test-logloss:0.26354	test-recall:0.99893
# [124]	test-logloss:0.26355	test-recall:0.99893
# [125]	test-logloss:0.26355	test-recall:0.99893
# [126]	test-logloss:0.26356	test-recall:0.99893
# [127]	test-logloss:0.26355	test-recall:0.99893
# [128]	test-logloss:0.26355	test-recall:0.99893
# [129]	test-logloss:0.26355	test-recall:0.99893
# [130]	test-logloss:0.26356	test-recall:0.99893
# [131]	test-logloss:0.26354	test-recall:0.99893
# [132]	test-logloss:0.26355	test-recall:0.99893
# [133]	test-logloss:0.26355	test-recall:0.99893
# [134]	test-logloss:0.26355	test-recall:0.99893
# [135]	test-logloss:0.26355	test-recall:0.99893
# [136]	test-logloss:0.26356	test-recall:0.99893
# [137]	test-logloss:0.26355	test-recall:0.99893
# [138]	test-logloss:0.26353	test-recall:0.99893
# [139]	test-logloss:0.26353	test-recall:0.99893
# [140]	test-logloss:0.26351	test-recall:0.99893
# [141]	test-logloss:0.26351	test-recall:0.99893
# [142]	test-logloss:0.26351	test-recall:0.99893
# [143]	test-logloss:0.26350	test-recall:0.99893
# [144]	test-logloss:0.26348	test-recall:0.99893
# [145]	test-logloss:0.26345	test-recall:0.99893
# [146]	test-logloss:0.26343	test-recall:0.99893
# [147]	test-logloss:0.26343	test-recall:0.99893
# [148]	test-logloss:0.26344	test-recall:0.99893
# [149]	test-logloss:0.26343	test-recall:0.99893
# [150]	test-logloss:0.26342	test-recall:0.99893
# [151]	test-logloss:0.26342	test-recall:0.99893
# [152]	test-logloss:0.26340	test-recall:0.99893
# [153]	test-logloss:0.26340	test-recall:0.99893
# [154]	test-logloss:0.26341	test-recall:0.99893
# [155]	test-logloss:0.26341	test-recall:0.99893
# [156]	test-logloss:0.26340	test-recall:0.99893
# [157]	test-logloss:0.26340	test-recall:0.99893
# [158]	test-logloss:0.26340	test-recall:0.99893
# [159]	test-logloss:0.26340	test-recall:0.99893
# [160]	test-logloss:0.26339	test-recall:0.99893
# [161]	test-logloss:0.26338	test-recall:0.99893
# [162]	test-logloss:0.26339	test-recall:0.99893
# [163]	test-logloss:0.26339	test-recall:0.99893
# [164]	test-logloss:0.26336	test-recall:0.99893
# [165]	test-logloss:0.26336	test-recall:0.99893
# [166]	test-logloss:0.26336	test-recall:0.99893
# [167]	test-logloss:0.26336	test-recall:0.99893
# [168]	test-logloss:0.26337	test-recall:0.99893
# [169]	test-logloss:0.26336	test-recall:0.99893
# [170]	test-logloss:0.26335	test-recall:0.99893
# [171]	test-logloss:0.26336	test-recall:0.99893
# [172]	test-logloss:0.26336	test-recall:0.99893
# [173]	test-logloss:0.26335	test-recall:0.99893
# [174]	test-logloss:0.26334	test-recall:0.99893
# [175]	test-logloss:0.26334	test-recall:0.99893
# [176]	test-logloss:0.26334	test-recall:0.99893
# [177]	test-logloss:0.26333	test-recall:0.99893
# [178]	test-logloss:0.26334	test-recall:0.99893
# [179]	test-logloss:0.26334	test-recall:0.99893
# [180]	test-logloss:0.26332	test-recall:0.99893
# [181]	test-logloss:0.26331	test-recall:0.99893
# [182]	test-logloss:0.26330	test-recall:0.99893
# [183]	test-logloss:0.26330	test-recall:0.99893
# [184]	test-logloss:0.26331	test-recall:0.99893
# [185]	test-logloss:0.26332	test-recall:0.99893
# [186]	test-logloss:0.26332	test-recall:0.99893
# [187]	test-logloss:0.26332	test-recall:0.99893
# [188]	test-logloss:0.26332	test-recall:0.99893
# [189]	test-logloss:0.26332	test-recall:0.99893
# [190]	test-logloss:0.26332	test-recall:0.99893
# [191]	test-logloss:0.26333	test-recall:0.99893
# [192]	test-logloss:0.26333	test-recall:0.99893
# [193]	test-logloss:0.26333	test-recall:0.99893
# [194]	test-logloss:0.26331	test-recall:0.99893
# [195]	test-logloss:0.26331	test-recall:0.99893
# [196]	test-logloss:0.26331	test-recall:0.99893
# [197]	test-logloss:0.26330	test-recall:0.99893
# [198]	test-logloss:0.26327	test-recall:0.99893
# [199]	test-logloss:0.26328	test-recall:0.99893

# %% [markdown]
# Since we have a low threshold for assigning a customer to the interested group, the recall is very high. We can see that logloss is decreasing during training.

# %%
xgb.plot_importance(xgb_cl)
important_features = xgb_cl.get_score(importance_type='weight')

# %% [markdown]
# Let's get a feeling how the model predicts interest.

# %%
def predict_and_plot(xgb_cl, data, true_labels, dataset_name, threshold=P_THRESHOLD):
    pred_prob = xgb_cl.predict(data)
    pred_label = (pred_prob > threshold).astype(int)
    cm = confusion_matrix(true_labels, pred_label, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'{dataset_name} Confusion Matrix')
    plt.show()
    return pred_prob, pred_label

y_train_pred_prob, y_train_pred_label = predict_and_plot(xgb_cl, dtrain, y_train, 'Training')
y_valid_pred_prob, y_valid_pred_labels = predict_and_plot(xgb_cl, dvalid, y_valid, 'Validation')

# %% [markdown]
# The confusion matrix shows that the model is able to predict the interested customers quite well (as expected ~`P_THRESHOLD` share of interested customers is wrongly assigned). However, the precision is quite low - a little bit more than half of the non-interested customers are assigned to the interested group. This means that the model predicts >50% false positives. This is at first not a big problem since we want to reach out to as many interested customers as possible, however, this might annoy non-interested customers.
#
# We want to inspect the precision-recall trade-off.

# %%
precision_train, recall_train, _ = precision_recall_curve(y_train, y_train_pred_prob)
precision_valid, recall_valid, _ = precision_recall_curve(y_valid, y_valid_pred_prob)

plt.plot(recall_train, precision_train, label='Training PR Curve', linestyle='-', color='blue')
plt.plot(recall_valid, precision_valid, label='Validation PR Curve', linestyle='--', color='orange')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()

plt.show()

# %% [markdown]
# The plot reveals that the model has generally a low precision. However, the precision does not drop significantly when the recall is increased. This is good since we want to have a high recall while retaining a high precision.
#
# Confusion matrix and precision-recall plots show that there is only little difference between training and validation data. This is good, the model generalizes well.
#
#
# **How to improve the model?**
#
# - Tune hyperparameters (e.g. `max_depth`, `n_estimators`, `learning_rate`, etc.)
# - Use different models (e.g. Random Forest, SVM, etc.) and ensemble methods
# - Use k-fold cross-validation to get a better estimate of the model performance
# - Use more advanced feature engineering techniques (e.g. PCA, feature selection, etc.)
# - Use more advanced techniques to handle the imbalanced dataset (e.g. oversampling the minority but interested class, undersampling the majority but non-interested class, etc.)

# %% [markdown]
# ## Create test submission file
#
# Since we assume that the missing values in the interest dataframe are the test data, we can create a submission file with the same length as the interest dataframe.

# %%
dtest = xgb.DMatrix(df_no_label.drop(columns=DROP_FEATS))
y_pred_no_label = xgb_cl.predict(dtest)

df_submission = pd.DataFrame({"id": df_no_label_ids, LABEL: y_pred_no_label}).sort_values("id").reset_index(drop=True)
df_submission.to_csv(os.path.join(DATA_D03_FOLDER_PATH, "submission.csv"), index=False)
df_submission
# Out:
#             id  Interesse
# 0       381110   0.000699
# 1       381111   0.325138
# 2       381112   0.305196
# 3       381113   0.006539
# 4       381114   0.000492
# ...        ...        ...
# 127032  508142   0.000278
# 127033  508143   0.367582
# 127034  508144   0.000332
# 127035  508145   0.000245
# 127036  508146   0.001209
#
# [127037 rows x 2 columns]
